# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/belgium_masterfile.csv"
bel_df = pd.read_csv(file_1)
bel_df.head()
# Out:
#    Position                                Track Name         Artist  Streams  \
# 0         1                                   7 rings  Ariana Grande   400283
# 1         2  break up with your girlfriend, i'm bored  Ariana Grande   294843
# 2         3                          Sweet but Psycho        Ava Max   232864
# 3         4                             bury a friend  Billie Eilish   218172
# 4         5                                   Shallow      Lady Gaga   216018
#
#                                                  URL        Week   Region
# 0  https://open.spotify.com/track/6ocbgoVGwYJhOv1...  2019-02-15  Belgium
# 1  https://open.spotify.com/track/4kV4N9D1iKVxx1K...  2019-02-15  Belgium
# 2  https://open.spotify.com/track/25sgk305KZfyuqV...  2019-02-15  Belgium
# 3  https://open.spotify.com/track/4NzMOnvSJVNKF7n...  2019-02-15  Belgium
# 4  https://open.spotify.com/track/2VxeLyX666F8uXC...  2019-02-15  Belgium

# %%
top_10 = bel_df.nlargest(30,'Streams')
print(top_10)
# Out:
#       Position                                     Track Name         Artist  \
# 400          1                                   Dance Monkey    Tones And I
# 1800         1                                   Dance Monkey    Tones And I
# 3600         1                                   Dance Monkey    Tones And I
# 3400         1                                   Dance Monkey    Tones And I
# 6200         1                                   Dance Monkey    Tones And I
# 2000         1                                   Dance Monkey    Tones And I
# 6800         1                                   Dance Monkey    Tones And I
# 9200         1                                   Dance Monkey    Tones And I
# 7400         1                                   Dance Monkey    Tones And I
# 8600         1                                   Dance Monkey    Tones And I
# 7200         1                                   Dance Monkey    Tones And I
# ...
