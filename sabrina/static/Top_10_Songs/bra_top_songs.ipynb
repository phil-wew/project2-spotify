# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/brazil_masterfile.csv"
bra_df = pd.read_csv(file_1)
bra_df.head()
# Out:
#    Position                       Track Name               Artist  Streams  \
# 0         1            Atrasadinha - Ao Vivo        Felipe Araújo  5517626
# 1         2                 Parado no Bailão        MC L da Vinte  4439458
# 2         3  Notificação Preferida - Ao Vivo  Zé Neto & Cristiano  4345439
# 3         4               Ciumeira - Ao Vivo     Marília Mendonça  4161551
# 4         5                     Quem Me Dera       Márcia Fellipe  3989150
#
#                                                  URL        Week  Region
# 0  https://open.spotify.com/track/5EKHbW7mXcAR4hC...  2019-01-04  Brazil
# 1  https://open.spotify.com/track/3Hb9kUdm4yf839F...  2019-01-04  Brazil
# 2  https://open.spotify.com/track/2qkNnJvQvhLiZ63...  2019-01-04  Brazil
# 3  https://open.spotify.com/track/2H1liABu20HXBOm...  2019-01-04  Brazil
# 4  https://open.spotify.com/track/2lAyctg5FocS67e...  2019-01-04  Brazil

# %%
top_10 = bra_df.nlargest(20,'Streams')
print(top_10)
# Out:
#        Position                    Track Name              Artist  Streams  \
# 9600          1          Liberdade Provisória  Henrique & Juliano  6454895
# 3800          1                   Bola Rebola          Tropkillaz  6000584
# 9800          1                       Jenifer       Gabriel Diniz  5872841
# 6000          1          Liberdade Provisória  Henrique & Juliano  5693358
# 1800          1  Combatchy (feat. MC Rebecca)              Anitta  5658600
# 0             1         Atrasadinha - Ao Vivo       Felipe Araújo  5517626
# 600           1                     Terremoto              Anitta  4951210
# 10000         1  Combatchy (feat. MC Rebecca)              Anitta  4922072
# 6001          2  Combatchy (feat. MC Rebecca)              Anitta  4825046
# 9601          2  Combatchy (feat. MC Rebecca)              Anitta  4792426
# 9602          3                      SENTADÃO       PEDRO SAMPAIO  4790485
# ...
