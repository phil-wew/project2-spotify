# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/chile_masterfile.csv"
chi_df = pd.read_csv(file_1)
chi_df.head()
# Out:
#    Position      Track Name        Artist  Streams  \
# 0         1  No Te Enamores   Paloma Mami  2217848
# 1         2   Calma - Remix    Pedro Capó  2107446
# 2         3      Adan y Eva  Paulo Londra  1950234
# 3         4         Amanece      Anuel AA  1749380
# 4         5      Not Steady   Paloma Mami  1684747
#
#                                                  URL        Week Region
# 0  https://open.spotify.com/track/0EJu1RBtxzldMG2...  2019-01-04  Chile
# 1  https://open.spotify.com/track/5iwz1NiezX7WWjn...  2019-01-04  Chile
# 2  https://open.spotify.com/track/6FyRXC8tJUh863J...  2019-01-04  Chile
# 3  https://open.spotify.com/track/1LiN0Z98FkR1t0m...  2019-01-04  Chile
# 4  https://open.spotify.com/track/42ArfZUgGo3k5bt...  2019-01-04  Chile

# %%
top_10 = chi_df.nlargest(20,'Streams')
print(top_10)
# Out:
#       Position          Track Name       Artist  Streams  \
# 5400         1             Fingías  Paloma Mami  4954532
# 3400         1               China     Anuel AA  4130467
# 3200         1               China     Anuel AA  3971494
# 1000         1               China     Anuel AA  3801821
# 2000         1            Callaita    Bad Bunny  3745411
# 600          1          Otro Trago         Sech  3532448
# 2800         1          Otro Trago         Sech  3477812
# 6800         1          Otro Trago         Sech  3361597
# 3000         1            Callaita    Bad Bunny  3327233
# 7800         1          Otro Trago         Sech  3321572
# 6400         1               China     Anuel AA  3276740
# 2001         2          Otro Trago         Sech  3208966
# 9000         1             Fingías  Paloma Mami  3185014
# 3201         2  Otro Trago - Remix         Sech  3104054
# 3001         2          Otro Trago         Sech  3091711
# ...
