# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/bulgaria_masterfile.csv"
bul_df = pd.read_csv(file_1)
bul_df.head()
# Out:
#    Position           Track Name         Artist  Streams  \
# 0         1         Dance Monkey    Tones And I    30965
# 1         2            Heartless     The Weeknd    27184
# 2         3  HIGHEST IN THE ROOM   Travis Scott    22971
# 3         4      Blinding Lights     The Weeknd    22884
# 4         5              Falling  Trevor Daniel    21175
#
#                                                  URL        Week    Region
# 0  https://open.spotify.com/track/1rgnBhdG2JDFTbY...  2019-12-20  Bulgaria
# 1  https://open.spotify.com/track/57vxBYXtHMk6H1a...  2019-12-20  Bulgaria
# 2  https://open.spotify.com/track/3eekarcy7kvN4yt...  2019-12-20  Bulgaria
# 3  https://open.spotify.com/track/0sf12qNH5qcw8qp...  2019-12-20  Bulgaria
# 4  https://open.spotify.com/track/4TnjEaWOeW0eKTK...  2019-12-20  Bulgaria

# %%
top_10 = bul_df.nlargest(20,'Streams')
print(top_10)
# Out:
#       Position                                         Track Name  \
# 800          1                                            7 rings
# 2200         1           break up with your girlfriend, i'm bored
# 4400         1                                HIGHEST IN THE ROOM
# 1800         1                                           Señorita
# 2201         2                                            7 rings
# 9600         1                                          Heartless
# 2800         1                                            7 rings
# 6800         1                                          Da Ili Ne
# 3400         1                                               Твой
# 3000         1                                            bad guy
# 4800         1                                           Señorita
# 5600         1  Don’t Call Me Angel (Charlie’s Angels) (with M...
# 400          1                                HIGHEST IN THE ROOM
# ...
