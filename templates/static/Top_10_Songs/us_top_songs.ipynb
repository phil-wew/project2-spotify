# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/US_masterfile.csv"
us_df = pd.read_csv(file_1)
us_df.head()
# Out:
#    Position                                     Track Name         Artist  \
# 0         1  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 1         2                                           Wow.    Post Malone
# 2         3                        Going Bad (feat. Drake)      Meek Mill
# 3         4                                     SICKO MODE   Travis Scott
# 4         5                                  thank u, next  Ariana Grande
#
#     Streams                                                URL        Week  \
# 0  13376854  https://open.spotify.com/track/3KkXRkHbMCARz0a...  2019-01-04
# 1  13236038  https://open.spotify.com/track/6MWtB6iiXyIwun0...  2019-01-04
# 2   9244190  https://open.spotify.com/track/2IRZnDFmlqMuOrY...  2019-01-04
# 3   9236076  https://open.spotify.com/track/2xLMifQCjDGFmkH...  2019-01-04
# 4   9173689  https://open.spotify.com/track/2rPE9A1vEgShuZx...  2019-01-04
#
#                      Region
# 0  United States of America
# ...

# %%
top_10 = us_df.nlargest(20,'Streams')
print(top_10)
# Out:
#        Position                                         Track Name  \
# 6800          1                                            7 rings
# 5400          1           break up with your girlfriend, i'm bored
# 5401          2                                            7 rings
# 1400          1      Old Town Road (feat. Billy Ray Cyrus) - Remix
# 9200          1                                       MIDDLE CHILD
# 7600          1                                HIGHEST IN THE ROOM
# 9201          2                                            7 rings
# 4800          1                                            Circles
# 9000          1                                            bad guy
# 200           1                                            7 rings
# 9400          1      Old Town Road (feat. Billy Ray Cyrus) - Remix
# 2600          1                                             Sucker
# 8000          1                                            7 rings
# ...
