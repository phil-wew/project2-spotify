# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#Creating names for files to read in to
file_1 = "../data/switzerland_masterfile.csv"
swi_df = pd.read_csv(file_1)
swi_df.head()
# Out:
#    Position                 Track Name        Artist  Streams  \
# 0         1        HIGHEST IN THE ROOM  Travis Scott   507969
# 1         2               Dance Monkey   Tones And I   460707
# 2         3                        110   Capital Bra   356728
# 3         4  Berlin lebt wie nie zuvor   Capital Bra   297473
# 4         5                   Señorita  Shawn Mendes   233705
#
#                                                  URL        Week       Region
# 0  https://open.spotify.com/track/3eekarcy7kvN4yt...  2019-10-11  Switzerland
# 1  https://open.spotify.com/track/1rgnBhdG2JDFTbY...  2019-10-11  Switzerland
# 2  https://open.spotify.com/track/67ojvEGRPAUCOoh...  2019-10-11  Switzerland
# 3  https://open.spotify.com/track/2pfio0uHpT4USTP...  2019-10-11  Switzerland
# 4  https://open.spotify.com/track/6v3KW9xbzN5yKLt...  2019-10-11  Switzerland

# %%
top_10 = swi_df.nlargest(20,'Streams')
print(top_10)
# Out:
#        Position                       Track Name        Artist  Streams  \
# 2800          1                          Tilidin   Capital Bra   746107
# 7000          1                      Wieder Lila         Samra   611926
# 3600          1                      Cherry Lady   Capital Bra   603027
# 6800          1                         Señorita  Shawn Mendes   557051
# 800           1                         Señorita  Shawn Mendes   537786
# 6000          1    Der Bratan bleibt der gleiche   Capital Bra   529574
# 8800          1                              110   Capital Bra   516459
# 1400          1                         Wolke 10          MERO   515245
# 4000          1                       Wir ticken   Capital Bra   514844
# 0             1              HIGHEST IN THE ROOM  Travis Scott   507969
# 4400          1                         Nautilus        Shindy   503981
# 3200          1                     Dance Monkey   Tones And I   503846
# ...
